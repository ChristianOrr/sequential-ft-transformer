# %%
import os
import pandas as pd
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
from tensorflow.keras.callbacks import EarlyStopping

from sequential_ft_transformer.fttransformer import ft_transformer
from sequential_ft_transformer.preprocessing import sq_df_to_dataset, download_data
from sequential_ft_transformer.plotting import plot_importances, plot_training_hist
# Out:
# 2024-01-02 17:02:53.239835: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-02 17:02:53.242211: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-02 17:02:53.281311: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-02 17:02:53.281381: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-02 17:02:53.282678: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-02 17:02:53.290121: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-02 17:02:53.291535: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-02 17:02:54.278624: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Download Data

# %%
data_folder = "../data/"
seq_length = 1

# %%
CSV_HEADER = [
    "age",
    "workclass",
    "fnlwgt",
    "education",
    "education_num",
    "marital_status",
    "occupation",
    "relationship",
    "race",
    "gender",
    "capital_gain",
    "capital_loss",
    "hours_per_week",
    "native_country",
    "income_bracket",
]

train_data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
test_data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test"

download_data(train_data_url, data_folder, "adult_train.csv")
download_data(test_data_url, data_folder, "adult_test.csv")

train_data = pd.read_csv(os.path.join(data_folder, "adult_train.csv"), header=None, names=CSV_HEADER)
test_data = pd.read_csv(os.path.join(data_folder, "adult_test.csv"), header=None, names=CSV_HEADER)

print(f"Train dataset shape: {train_data.shape}")
print(f"Test dataset shape: {test_data.shape}")
# Out:
# adult_train.csv already exists in ../data/
# adult_test.csv already exists in ../data/
# Train dataset shape: (32561, 15)
# Test dataset shape: (16282, 15)

# %%
train_data.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country income_bracket
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K

# %% [markdown]
# ## Preprocess

# %%
# Column information
NUMERIC_FEATURES = ['age', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']
NUMERIC_FEATURES = sorted(NUMERIC_FEATURES)
CATEGORICAL_FEATURES = ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'gender', 'native_country']
CATEGORICAL_FEATURES = sorted(CATEGORICAL_FEATURES)

FEATURES = sorted(list(NUMERIC_FEATURES) + list(CATEGORICAL_FEATURES))
LABEL = 'income_bracket'

# %%
# encoding as binary target
train_data[LABEL] = train_data[LABEL].apply(lambda x: int(x == ' >50K')) 
test_data[LABEL] = test_data[LABEL].apply(lambda x: int(x == ' >50K.'))

# %%
train_data = train_data.dropna()
test_data = test_data.dropna()

# %%
train_input = train_data[FEATURES]
train_labels = train_data[LABEL]

test_input = test_data[FEATURES]
test_labels = test_data[LABEL]

# %% [markdown]
# ## Get Lookup Tables for Each Categorical Column

# %%
cat_lookups = dict()
feature_unique_counts = dict()
num_oov_indices = 1
for cat in CATEGORICAL_FEATURES:
    unique_values = list(np.unique(train_input[cat]).astype(str))
    feature_unique_counts[cat] = len(unique_values) + num_oov_indices
    lookup = tf.keras.layers.StringLookup(vocabulary=unique_values, num_oov_indices=num_oov_indices)
    cat_lookups[cat] = lookup
# Out:
# 2024-01-02 17:02:55.959314: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-01-02 17:02:55.959655: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ## Convert Each Categorical String to an ID

# %%
for cat in CATEGORICAL_FEATURES:
    train_input[cat] = cat_lookups[cat](train_input[cat])
    test_input[cat] = cat_lookups[cat](test_input[cat])
# Out:
# /tmp/ipykernel_774061/1451819549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_input[cat] = cat_lookups[cat](train_input[cat])
# /tmp/ipykernel_774061/1451819549.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input[cat] = cat_lookups[cat](test_input[cat])

# %%
train_input.loc[:, CATEGORICAL_FEATURES] = train_input[CATEGORICAL_FEATURES].astype(int)
test_input.loc[:, CATEGORICAL_FEATURES] = test_input[CATEGORICAL_FEATURES].astype(int)

train_input.loc[:, NUMERIC_FEATURES] = train_input[NUMERIC_FEATURES].astype(float)
test_input.loc[:, NUMERIC_FEATURES] = test_input[NUMERIC_FEATURES].astype(float)

# %%
train_labels = train_labels.to_frame(name=LABEL)
test_labels = test_labels.to_frame(name=LABEL)

# %%
x_train, x_val, y_train, y_val = train_test_split(train_input, train_labels, test_size=0.2)

# %% [markdown]
# ## Create TF Datasets

# %%
batch_size = 1000
train_dataset = sq_df_to_dataset(
    x_train, 
    seq_length, 
    target_df=y_train, 
    target=LABEL, 
    categorical_features=CATEGORICAL_FEATURES, 
    numerical_features=NUMERIC_FEATURES, 
    batch_size=batch_size
)
val_dataset = sq_df_to_dataset(
    x_val, 
    seq_length, 
    target_df=y_val, 
    target=LABEL, 
    categorical_features=CATEGORICAL_FEATURES, 
    numerical_features=NUMERIC_FEATURES, 
    shuffle=False, # No shuffle
    batch_size=batch_size
)  
test_dataset = sq_df_to_dataset(
    test_input, 
    seq_length, 
    categorical_features=CATEGORICAL_FEATURES, 
    numerical_features=NUMERIC_FEATURES, 
    shuffle=False, 
    batch_size=batch_size) # No target, no shuffle

# %% [markdown]
# ## Periodic Numerical Embedding FT-Transformer

# %%
EXPLANATIONS = True
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001
NUM_EPOCHS = 10
N_BINS = 10

# %%
model = ft_transformer(
    out_dim=1,
    out_activation='sigmoid',
    numerical_features = NUMERIC_FEATURES,
    categorical_features = CATEGORICAL_FEATURES,
    feature_unique_counts = feature_unique_counts,
    seq_length=seq_length,
    numerical_embedding_type='periodic',
    n_bins=N_BINS,
    explainable=EXPLANATIONS
)


optimizer = tf.keras.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

loss_dict = {"output": tf.keras.losses.BinaryCrossentropy()}
metrics_dict = {"output": [tf.keras.metrics.AUC(name="PR AUC", curve='PR')]}
if EXPLANATIONS:
    loss_dict.update({"importances": None})
    metrics_dict.update({"importances": None})
model.compile(
    optimizer = optimizer,
    loss = loss_dict,
    metrics= metrics_dict,
)

early = EarlyStopping(monitor="val_loss", mode="min", patience=20, restore_best_weights=True)
callback_list = [early]
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.einsum), but are not present in its tracked objects:   <tf.Variable 'Variable:0' shape=(1, 5, 20, 32) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.

# %%
hist = model.fit(
    train_dataset, 
    epochs=NUM_EPOCHS, 
    validation_data=val_dataset,
    callbacks=callback_list
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['layer_normalization_1/gamma:0', 'layer_normalization_1/beta:0', 'layer_normalization_3/gamma:0', 'layer_normalization_3/beta:0', 'layer_normalization_5/gamma:0', 'layer_normalization_5/beta:0', 'multi_head_attention/query/kernel:0', 'multi_head_attention/query/bias:0', 'multi_head_attention/key/kernel:0', 'multi_head_attention/key/bias:0', 'multi_head_attention/value/kernel:0', 'multi_head_attention/value/bias:0', 'multi_head_attention/attention_output/kernel:0', 'multi_head_attention/attention_output/bias:0', 'multi_head_attention_1/query/kernel:0', 'multi_head_attention_1/query/bias:0', 'multi_head_attention_1/key/kernel:0', 'multi_head_attention_1/key/bias:0', 'multi_head_attention_1/value/kernel:0', 'multi_head_attention_1/value/bias:0', 'multi_head_attention_1/attention_output/kernel:0', 'multi_head_attention_1/attention_output/bias:0', 'multi_head_attention_2/query/kernel:0', 'multi_head_attention_2/query/bias:0', 'multi_head_attention_2/key/kernel:0', 'multi_head_attention_2/key/bias:0', 'multi_head_attention_2/value/kernel:0', 'multi_head_attention_2/value/bias:0', 'multi_head_attention_2/attention_output/kernel:0', 'multi_head_attention_2/attention_output/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['layer_normalization_1/gamma:0', 'layer_normalization_1/beta:0', 'layer_normalization_3/gamma:0', 'layer_normalization_3/beta:0', 'layer_normalization_5/gamma:0', 'layer_normalization_5/beta:0', 'multi_head_attention/query/kernel:0', 'multi_head_attention/query/bias:0', 'multi_head_attention/key/kernel:0', 'multi_head_attention/key/bias:0', 'multi_head_attention/value/kernel:0', 'multi_head_attention/value/bias:0', 'multi_head_attention/attention_output/kernel:0', 'multi_head_attention/attention_output/bias:0', 'multi_head_attention_1/query/kernel:0', 'multi_head_attention_1/query/bias:0', 'multi_head_attention_1/key/kernel:0', 'multi_head_attention_1/key/bias:0', 'multi_head_attention_1/value/kernel:0', 'multi_head_attention_1/value/bias:0', 'multi_head_attention_1/attention_output/kernel:0', 'multi_head_attention_1/attention_output/bias:0', 'multi_head_attention_2/query/kernel:0', 'multi_head_attention_2/query/bias:0', 'multi_head_attention_2/key/kernel:0', 'multi_head_attention_2/key/bias:0', 'multi_head_attention_2/value/kernel:0', 'multi_head_attention_2/value/bias:0', 'multi_head_attention_2/attention_output/kernel:0', 'multi_head_attention_2/attention_output/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['layer_normalization_1/gamma:0', 'layer_normalization_1/beta:0', 'layer_normalization_3/gamma:0', 'layer_normalization_3/beta:0', 'layer_normalization_5/gamma:0', 'layer_normalization_5/beta:0', 'multi_head_attention/query/kernel:0', 'multi_head_attention/query/bias:0', 'multi_head_attention/key/kernel:0', 'multi_head_attention/key/bias:0', 'multi_head_attention/value/kernel:0', 'multi_head_attention/value/bias:0', 'multi_head_attention/attention_output/kernel:0', 'multi_head_attention/attention_output/bias:0', 'multi_head_attention_1/query/kernel:0', 'multi_head_attention_1/query/bias:0', 'multi_head_attention_1/key/kernel:0', 'multi_head_attention_1/key/bias:0', 'multi_head_attention_1/value/kernel:0', 'multi_head_attention_1/value/bias:0', 'multi_head_attention_1/attention_output/kernel:0', 'multi_head_attention_1/attention_output/bias:0', 'multi_head_attention_2/query/kernel:0', 'multi_head_attention_2/query/bias:0', 'multi_head_attention_2/key/kernel:0', 'multi_head_attention_2/key/bias:0', 'multi_head_attention_2/value/kernel:0', 'multi_head_attention_2/value/bias:0', 'multi_head_attention_2/attention_output/kernel:0', 'multi_head_attention_2/attention_output/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['layer_normalization_1/gamma:0', 'layer_normalization_1/beta:0', 'layer_normalization_3/gamma:0', 'layer_normalization_3/beta:0', 'layer_normalization_5/gamma:0', 'layer_normalization_5/beta:0', 'multi_head_attention/query/kernel:0', 'multi_head_attention/query/bias:0', 'multi_head_attention/key/kernel:0', 'multi_head_attention/key/bias:0', 'multi_head_attention/value/kernel:0', 'multi_head_attention/value/bias:0', 'multi_head_attention/attention_output/kernel:0', 'multi_head_attention/attention_output/bias:0', 'multi_head_attention_1/query/kernel:0', 'multi_head_attention_1/query/bias:0', 'multi_head_attention_1/key/kernel:0', 'multi_head_attention_1/key/bias:0', 'multi_head_attention_1/value/kernel:0', 'multi_head_attention_1/value/bias:0', 'multi_head_attention_1/attention_output/kernel:0', 'multi_head_attention_1/attention_output/bias:0', 'multi_head_attention_2/query/kernel:0', 'multi_head_attention_2/query/bias:0', 'multi_head_attention_2/key/kernel:0', 'multi_head_attention_2/key/bias:0', 'multi_head_attention_2/value/kernel:0', 'multi_head_attention_2/value/bias:0', 'multi_head_attention_2/attention_output/kernel:0', 'multi_head_attention_2/attention_output/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 27/27 [==============================] - 10s 215ms/step - loss: 0.4365 - output_loss: 0.4365 - output_PR AUC: 0.5401 - val_loss: 0.3853 - val_output_loss: 0.3853 - val_output_PR AUC: 0.6156
# Epoch 2/10
# 27/27 [==============================] - 5s 201ms/step - loss: 0.3817 - output_loss: 0.3817 - output_PR AUC: 0.6388 - val_loss: 0.3653 - val_output_loss: 0.3653 - val_output_PR AUC: 0.6408
# Epoch 3/10
# 27/27 [==============================] - 5s 188ms/step - loss: 0.3620 - output_loss: 0.3620 - output_PR AUC: 0.6811 - val_loss: 0.3523 - val_output_loss: 0.3523 - val_output_PR AUC: 0.6852
# Epoch 4/10
# 27/27 [==============================] - 5s 196ms/step - loss: 0.3531 - output_loss: 0.3531 - output_PR AUC: 0.7066 - val_loss: 0.3496 - val_output_loss: 0.3496 - val_output_PR AUC: 0.7124
# Epoch 5/10
# 27/27 [==============================] - 5s 192ms/step - loss: 0.3497 - output_loss: 0.3497 - output_PR AUC: 0.7127 - val_loss: 0.3452 - val_output_loss: 0.3452 - val_output_PR AUC: 0.7184
# Epoch 6/10
# 27/27 [==============================] - 5s 193ms/step - loss: 0.3444 - output_loss: 0.3444 - output_PR AUC: 0.7195 - val_loss: 0.3458 - val_output_loss: 0.3458 - val_output_PR AUC: 0.7186
# Epoch 7/10
# 27/27 [==============================] - 6s 218ms/step - loss: 0.3430 - output_loss: 0.3430 - output_PR AUC: 0.7253 - val_loss: 0.3434 - val_output_loss: 0.3434 - val_output_PR AUC: 0.7188
# Epoch 8/10
# 27/27 [==============================] - 6s 211ms/step - loss: 0.3420 - output_loss: 0.3420 - output_PR AUC: 0.7269 - val_loss: 0.3410 - val_output_loss: 0.3410 - val_output_PR AUC: 0.7291
# Epoch 9/10
# 27/27 [==============================] - 6s 208ms/step - loss: 0.3400 - output_loss: 0.3400 - output_PR AUC: 0.7285 - val_loss: 0.3422 - val_output_loss: 0.3422 - val_output_PR AUC: 0.7294
# Epoch 10/10
# 27/27 [==============================] - 6s 225ms/step - loss: 0.3380 - output_loss: 0.3380 - output_PR AUC: 0.7348 - val_loss: 0.3406 - val_output_loss: 0.3406 - val_output_PR AUC: 0.7323

# %%
hist_plot = plot_training_hist(hist.history, EXPLANATIONS)

# %%
preds = model.predict(test_dataset)
print("Test ROC AUC:", np.round(roc_auc_score(test_data[LABEL], preds['output'].ravel()), 4))
print("Test PR AUC:", np.round(average_precision_score(test_data[LABEL], preds['output'].ravel()), 4))
print("Test Accuracy:", np.round(accuracy_score(test_data[LABEL], preds['output'].ravel()>0.5), 4))

# Reported accuracy - 0.858
# Out:
# 17/17 [==============================] - 3s 155ms/step
# Test ROC AUC: 0.8929
# Test PR AUC: 0.7288
# Test Accuracy: 0.8447

# %% [markdown]
# ## Explainability

# %%
if 'importances' in preds.keys():
    importances = preds['importances']
    importances_df = pd.DataFrame(importances[:, :-1], columns = FEATURES)
    importances_fig, total_importances = plot_importances(
        importances_df, 
        title="Importances for FT-Transformer"
    )
